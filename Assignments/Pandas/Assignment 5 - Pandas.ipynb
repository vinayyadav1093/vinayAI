# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import pandas as pd

URL = "https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv"
df = pd.read_csv(URL)
df.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %% [markdown]
# Questions

# %% [markdown]
# 1. Delete unnamed columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258000 entries, 0 to 257999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   year     258000 non-null  int64
#  1   name     258000 non-null  object
#  2   percent  258000 non-null  float64
#  3   sex      258000 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 7.9+ MB

# %%
df.isnull().any()
# Out:
# year       False
# name       False
# percent    False
# sex        False
# dtype: bool

# %% [markdown]
# 2. Show the distribution of male and female

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
df.sex.value_counts()
sns.distplot([1 if i=="boy" else 0 for i in df.sex ])
plt.xticks([0,1])
plt.title("Girl and Boy distribution plot");
sns.catplot(x="sex", kind="count", data=df, alpha=0.5);

# %% [markdown]
# 3. Show the top 5 most preferred names

# %%
df.name.value_counts(ascending=False)[:5].to_frame()
# Out:
#            name
# Jessie      258
# Leslie      247
# Guadalupe   244
# Jean        244
# Lee         240

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
print(df.name.value_counts(ascending=False)[df.name.value_counts(ascending=False) == 19.0].index)
# Out:
# Index(['Alba', 'Juli', 'Haleigh', 'Oneal', 'Newt', 'Laci', 'Lum', 'Nataly',
#        'Tiny', 'Kristoffer', 'Imani', 'Tawana', 'Monnie', 'Doshie', 'Dimple',
#        'Ami', 'Nakia', 'Tisha', 'Mannie', 'Trena', 'Yasmine', 'Dionne',
#        'Elois', 'Marilou', 'Phoenix', 'Salina', 'Shaina', 'Shelli', 'Brien',
#        'Milagros', 'Alena', 'Kenyatta', 'Zenobia', 'Oakley', 'Clemens',
#        'Adrain', 'Luciano', 'Raina', 'Daria', 'Genie', 'Jaylen', 'Vonnie',
#        'Corinna', 'Talon', 'Shakira', 'Camden', 'Lew', 'Harrell', 'Mariela',
#        'Giuseppe', 'Windell', 'Fabiola', 'Brynn', 'Eligah', 'Bobbye',
#        'Elberta', 'Rosendo', 'Dulce', 'Brooklyn', 'Rube', 'Johny', 'Aidan',
#        'Teena', 'Alline', 'Chiquita', 'Lavera', 'Kane', 'Olan', 'Eliana',
#        'Misael', 'Wayman', 'Nonie', 'Heaven', 'Marylin'],
#       dtype='object')

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
# no states column in the given dataframe

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
data = {"Max":[39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25],
        "Min":[21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]}

newDf = pd.DataFrame(data)
newDf
# Out:
#     Max  Min
# 0    39   21
# 1    41   23
# 2    43   27
# 3    47   28
# 4    49   32
# 5    51   35
# 6    45   31
# 7    38   28
# 8    37   21
# 9    29   19
# 10   27   17
# 11   25   18
